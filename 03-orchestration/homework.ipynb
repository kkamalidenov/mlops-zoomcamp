# %%
from IPython.display import Image
Image(filename='./q1_run_mage.png')

# %%
from IPython.display import Image
Image(filename='./q2_creating_a_project.png')

# %%
from IPython.display import Image
Image(filename='./q3_creating_a_pipeline.png')

# %%
from IPython.display import Image
Image(filename='./q4_data_preparation.png')

# %%
from IPython.display import Image
Image(filename='./q5_train_a_model.png')

# %%
from IPython.display import Image
Image(filename='./q6_register_the_model.png')
