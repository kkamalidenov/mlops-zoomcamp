# %%
# !mlflow --version
# Out:
# mlflow, version 2.17.1

# %%
# !python3 preprocess_data.py --raw_data_path ./trip-data --dest_path ./output

# %%
# !ls -1 ./output | wc -l
# Out:
#        4

# %%
# !python3 train.py
# Out:
# 2024/11/09 21:35:49 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'numpy.ndarray' object has no attribute 'toarray'
# /opt/homebrew/lib/python3.12/site-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# RMSE: 5.431160019389339
#
# Logged Model Parameters:
# bootstrap: True
# ccp_alpha: 0.0
# criterion: squared_error
# max_depth: 10
# max_features: 1.0
# max_leaf_nodes: None
# max_samples: None
# min_impurity_decrease: 0.0
# min_samples_leaf: 1
# min_samples_split: 2
# min_weight_fraction_leaf: 0.0
# monotonic_cst: None
# n_estimators: 100
# n_jobs: None
# oob_score: False
# random_state: 0
# verbose: 0
# warm_start: False
#
# The value of min_samples_split is: 2

# %%
# !python3 hpo.py
# Out:
#   0%|                                    | 0/15 [00:00<?, ?trial/s, best loss=?]/opt/homebrew/lib/python3.12/site-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
#
# 2024/11/09 22:08:09 INFO mlflow.tracking._tracking_service.client: 🏃 View run serious-grub-240 at: http://127.0.0.1:5050/#/experiments/2/runs/826489f70fbb4f5f93632ecf56c80772.
#
# 2024/11/09 22:08:09 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://127.0.0.1:5050/#/experiments/2.
#
#   7%|▋          | 1/15 [00:02<00:40,  2.91s/trial, best loss: 5.370086069268862]/opt/homebrew/lib/python3.12/site-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
# ...

# %%
from IPython.display import Image
Image(filename='./q5_tune_model_hyperparameters.png')

# %%
# !python3 register_model.py
# Out:
# 2024/11/09 22:43:45 INFO mlflow.tracking.fluent: Experiment with name 'random-forest-best-models' does not exist. Creating a new experiment.
# 2024/11/09 22:43:45 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'numpy.ndarray' object has no attribute 'toarray'
# /opt/homebrew/lib/python3.12/site-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# /opt/homebrew/lib/python3.12/site-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# ...

# %%
from IPython.display import Image
Image(filename='./q6_promote_the_best_model_to_the_model_registry.png')
